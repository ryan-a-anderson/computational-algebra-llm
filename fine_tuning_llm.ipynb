# %% [markdown]
# ## Macaulay2 QLoRA Pipeline on Qwen2.5-7B-Instruct Open-Source Large Language Model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Fine-tuning-LLM
# Out:
# /content/drive/MyDrive/Fine-tuning-LLM

# %% [markdown]
# Brief Overview:
# - QLoRA Fine-tuning Pipeline for Macaulay2 Large Language Model
# - Base Model: Qwen/Qen2.5-7B-Instruct
# - Environment: Google Colab Pro (NVIDIA A100 40GB VRAM)

# %%
# Dependencies

# !pip install -q -U \
    transformers==4.44.0 \
    peft==0.12.0 \
    trl==0.10.1 \
    bitsandbytes==0.43.3 \
    datasets==2.21.0 \
    "accelerate>=0.34.0" \
    wandb \
    scipy \
    "numpy>=2.0"

# %%
import json
import os
import random
from pathlib import Path
import torch
import wandb
import transformers
import peft
import trl
import datasets
import accelerate

from datasets import Dataset
from peft import (
    LoraConfig,
    TaskType,
    get_peft_model,
    prepare_model_for_kbit_training,
)
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    TrainingArguments
)
from trl import SFTConfig, SFTTrainer, DataCollatorForCompletionOnlyLM

print("transformers:", transformers.__version__)
print("peft:", peft.__version__)
print("trl:", trl.__version__)
print("datasets:", datasets.__version__)
print("accelerate:", accelerate.__version__)
# Out:
# transformers: 4.44.0
# peft: 0.12.0
# trl: 0.10.1
# datasets: 2.21.0
# accelerate: 1.13.0

# %%
# Fine-tuning configuration

CONFIG = {
    # Model & Data Config
    "base_model" : "Qwen/Qwen2.5-7B-Instruct",
    "data_path" : "/content/drive/MyDrive/Fine-tuning-LLM/unified_benchmark.json",
    "val_split" : 0.15,
    "seed" : 42,

    # LoRA Hyperparameters
    "lora_r" : 8,
    "lora_alpha" : 16,
    "lora_dropout" : 0.05,
    "lora_target_modules" : [
        "q_proj", "k_proj", "v_proj",
        "o_proj", "gate_proj", "up_proj", "down_proj"
    ],

    # Training Hyperparameters
    "num_epochs" : 3,
    "per_device_train_batch_size" : 2,
    "gradient_accumulation_steps" : 4,
    "learning_rate" : 2e-4,
    "lr_scheduler" : "cosine",
    "warmup_ratio" : 0.1,
    "max_seq_length" : 512,
    "weight_decay" : 0.01,

    "output_dir" : "./m2-qwen-qlora",
    "save_steps" : 20,
    "eval_steps" : 20,
    "logging_steps" : 5,
    "wandb_project" : "macaulay2-llm",
}

# %%
# Loading Dataset

# %%
# Loading Tokenizer

# %%
# Loading Quantized Model in GPU

# %%
# Attaching LoRA Adapters

# %%
# Completion-Only Collator

# %%
# Training Arguments & SFTTrainer

# %%
# Training Fine-tuned Model

# %%
# Merging LoRA Adapters into Base Model

# %%
# Inference
